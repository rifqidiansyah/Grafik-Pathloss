# %% [markdown]
# <a href="https://colab.research.google.com/github/rifqidiansyah/Grafik-Pathloss/blob/main/Tugas%2013_Rifqi%20diansyah_1101208278.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos(frek,tipe,ht,hr,d):
    if frek in range(150,1501):
        Ca=69.55
        Cb=26.16
    elif frek in range(1501,2001):
        Ca=46.3
        Cb=33.9
    
    if tipe=='urban' :
        Cm=0
    elif tipe=='suburban' :
        Cm= -2*((np.log10((frek/28)**2))-5.4)
    elif tipe=='open' :
        Cm= -4.78*(np.log10(frek))+18.33*(np.log10(frek))-40.94
    else :
        Cm='tipe salah'
    
    ahr = (1.1*np.log10(frek)-0.7)*hr-(1.56*np.log10(frek)-1.8)
    Lp = Ca+(Cb*np.log10(frek))-(13.83*np.log(ht))-ahr+((44.9-6.55*np.log10(ht))*np.log10(d))-Cm
    
    return Lp

# %%
f=1800 #MHz
loc1='urban'
loc2='open'
loc3='suburban'
tower=80 #m
user=1.5 #m
dmin=200 #m
dmax=700 #m
N=200 #titik
d=np.random.randint(dmin,dmax,N)

# %%
d_sort=d[np.argsort(d)]
LpUrban=cos(f,loc1,tower,user,d)
LpOpen=cos(f,loc2,tower,user,d)
LpSuburban=cos(f,loc3,tower,user,d)

# %%
y= Urban_sort=LpUrban[np.argsort(d)]
y2= Suburban_sort=LpSuburban[np.argsort(d)]
y3= Open_sort=LpOpen[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,y, label= 'Urban')
plt.plot(d_sort,y2, label= 'Suburban')
plt.plot(d_sort,y3, label= 'Open')
plt.legend()
plt.title('Frekuensi 1800 MHz')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()

# %%
f1=700 #MHz
f2=900
f3=1800
loc='urban'
tower=80 #m
user=1.5 #m
dmin=200 #m
dmax=700 #m
N=200 #titik
d=np.random.randint(dmin,dmax,N)

# %%
d_sort=d[np.argsort(d)]
LpUrban1=cos(f1,loc,tower,user,d)
LpUrban2=cos(f2,loc,tower,user,d)
LpUrban3=cos(f3,loc,tower,user,d)

# %%
y= Urban_sort=LpUrban1[np.argsort(d)]
y2= Urban_sort2=LpUrban2[np.argsort(d)]
y3= Urban_sort3=LpUrban3[np.argsort(d)]

# %%
plt.figure()
plt.plot(d_sort,y, label= '700')
plt.plot(d_sort,y2, label= '900')
plt.plot(d_sort,y3, label= '1800')
plt.legend()
plt.title('Model Urban')
plt.xlabel('Jarak (m)')
plt.ylabel('Path Loss (dB)')
plt.show()
